# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as pdr
from nsepy import get_history
from datetime import date

# %%
start = '2010-01-01'
end = '2019-12-31'
# sbin = get_history(symbol="SBIN", start=date(2015,1,1), end=date(2015,1,31))
from nsepython import *
# print(indices)
# positions = nsefetch('https://www.nseindia.com/api/equity-stockIndices?index=SECURITIES%20IN%20F%26O')
# df = pd.DataFrame(positions['data'])
# df = df.loc['ACC'][0]

# df = pdr.DataReader('AAPL', 'yahoo', start, end)
# df

# %%
# symbol = "SBIN"
# series = "EQ"
# start_date = "01-04-2015"
# end_date ="31-12-2023"
# # sbi = equity_history(symbol,series,start_date,end_date)
# df = pd.DataFrame(equity_history(symbol,series,start_date,end_date))
# df

# symbol = "NIFTY 50"
# start_date = "01-Mar-2011"
# end_date = "07-Jun-2021"
# df =(index_history(symbol,start_date,end_date))
# df

# %%
df
# Out:
#                            _id CH_SYMBOL CH_SERIES CH_MARKET_TYPE  \
# 0     6565d67eeebd226fdec8427f      SBIN        EQ              N
# 1     656727ff45164acaeba00300      SBIN        EQ              N
# 2     6568797e1ea8db58784026de      SBIN        EQ              N
# 3     6569cafed3a7a71b97dddf06      SBIN        EQ              N
# 4     656dbf7fd80444e5381699b8      SBIN        EQ              N
# ...                        ...       ...       ...            ...
# 2222  641eb352353f0e0007d24122      SBIN        EQ              N
# 2223  641eb35c5510ab0007ed954f      SBIN        EQ              N
# 2224  641eb367ff5c300007058b4d      SBIN        EQ              N
# 2225  641eb371353f0e0007d24848      SBIN        EQ              N
# 2226  641eb37bde5deb00074c344f      SBIN        EQ              N
#
#       CH_TRADE_HIGH_PRICE  CH_TRADE_LOW_PRICE  CH_OPENING_PRICE  \
# 0                  565.20              561.10            563.60
# 1                  569.00              565.10            568.00
# 2                  570.20              563.65            569.75
# 3                  574.20              566.55            567.00
# 4                  596.00              584.55            588.00
# ...                   ...                 ...               ...
# 2222               277.00              271.35            277.00
# 2223               273.60              263.25            271.45
# 2224               267.25              259.65            264.00
# 2225               268.00              260.30            264.00
# 2226               277.20              262.60            263.40
#
#       CH_CLOSING_PRICE  CH_LAST_TRADED_PRICE  CH_PREVIOUS_CLS_PRICE  ...  \
# 0               564.45                564.80                 560.35  ...
# 1               568.60                568.35                 564.45  ...
# 2               564.75                565.15                 568.60  ...
# 3               571.75                571.85                 564.75  ...
# 4               594.70                595.90                 571.75  ...
# ...                ...                   ...                    ...  ...
# 2222            272.05                272.50                 277.15  ...
