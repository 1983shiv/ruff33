# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as pdr
from nsepy import get_history
from datetime import date

# %%
start = '2010-01-01'
end = '2019-12-31'
# sbin = get_history(symbol="SBIN", start=date(2015,1,1), end=date(2015,1,31))
from nsepython import *
# print(indices)
# positions = nsefetch('https://www.nseindia.com/api/equity-stockIndices?index=SECURITIES%20IN%20F%26O')
# df = pd.DataFrame(positions['data'])
# df = df.loc['ACC'][0]

# df = pdr.DataReader('AAPL', 'yahoo', start, end)
# df

# %%
# symbol = "SBIN"
# series = "EQ"
# start_date = "01-04-2015"
# end_date ="31-12-2023"
# # sbi = equity_history(symbol,series,start_date,end_date)
# df = pd.DataFrame(equity_history(symbol,series,start_date,end_date))
# df

# symbol = "NIFTY 50"
# start_date = "01-Mar-2011"
# end_date = "07-Jun-2021"
# df =(index_history(symbol,start_date,end_date))
# df

# %%
sbin = pd.read_csv('train.csv')
sbin
# Out:
#       Unnamed: 0                       _id CH_SYMBOL CH_SERIES CH_MARKET_TYPE  \
# 0              0  658ac07e55487c5c282e52d6      SBIN        EQ              N
# 1              1  658c11ff3dcac5b895a9ab2a      SBIN        EQ              N
# 2              2  658d637e55a5f96115c518a5      SBIN        EQ              N
# 3              3  658eb4ff59ecfd0253b31b8f      SBIN        EQ              N
# 4              4  6554b3174157181b522b8daf      SBIN        EQ              N
# ...          ...                       ...       ...       ...            ...
# 2289        2289  6474799d4402980007ac71a4      SBIN        EQ              N
# 2290        2290  641eb1094438f60007b53b27      SBIN        EQ              N
# 2291        2291  641eb1133d38840007c63653      SBIN        EQ              N
# 2292        2292  641eb11d353f0e0007d22af0      SBIN        EQ              N
# 2293        2293  641eb127a077ee000756af18      SBIN        EQ              N
#
# ...

# %%
# data = pd.read_csv("sbin.csv")
sbin = sbin.rename(columns={'CH_SYMBOL':'symbol', 'CH_TRADE_HIGH_PRICE':'high', 'CH_TRADE_LOW_PRICE':'low', 'CH_OPENING_PRICE':'open', 'CH_CLOSING_PRICE':'close', 'CH_LAST_TRADED_PRICE':'ltp', 'CH_PREVIOUS_CLS_PRICE':'previous_close', 'CH_TOTAL_TRADES':'total_trades', 'CH_TIMESTAMP':'date', 'VWAP':'vwap', 'CH_TOT_TRADED_QTY':'total_traded_qty', 'CH_TOT_TRADED_VAL':'total_traded_volume', 'CH_52WEEK_HIGH_PRICE':'w52_high', 'CH_52WEEK_LOW_PRICE':'w52_low'})

# List of columns to be dropped
columns_to_drop = ['_id', 'symbol', 'CH_SERIES', 'CH_MARKET_TYPE', 'CH_ISIN', 'createdAt', 'mTIMESTAMP', 'TIMESTAMP', 'SLBMH_TOT_VAL', '__v', 'updatedAt', 'CA']

# Drop the specified columns
sbin = sbin.drop(columns=columns_to_drop)

unnamed_columns = [col for col in sbin.columns if 'Unnamed' in col]
sbin = sbin.drop(columns=unnamed_columns)
sbin
# Out:
#         high     low    open   close     ltp  previous_close  \
# 0     641.30  635.65  638.85  638.05  638.50          636.75
# 1     649.45  639.00  640.75  648.55  648.65          638.05
# 2     653.30  646.50  650.25  651.40  649.30          648.55
# 3     649.60  639.55  645.50  642.05  641.70          651.40
# 4     588.00  582.60  587.25  584.70  584.00          581.35
# ...      ...     ...     ...     ...     ...             ...
# 2289  302.95  291.90  302.70  293.05  292.55          300.30
# 2290  297.80  289.20  293.15  290.80  290.50          293.05
# 2291  294.85  285.70  291.00  290.30  291.20          290.80
# 2292  292.80  278.00  289.50  279.50  279.50          290.30
# 2293  290.80  275.70  277.50  287.30  289.75          279.50
#
#       total_traded_qty  total_traded_volume  w52_high  w52_low  total_trades  \
# 0             10153089         6.489769e+09    660.40   499.35        298625
# ...

# %%
sbin['date'] = pd.to_datetime(sbin['date'])

# %%
sbin.describe()
# Out:
#               high          low         open        close          ltp  \
# count  2294.000000  2294.000000  2294.000000  2294.000000  2294.000000
# mean    347.575719   338.767677   343.550828   342.992284   343.036813
# min     153.200000   148.250000   151.950000   150.850000   151.100000
# 25%     258.800000   253.000000   256.250000   255.612500   255.750000
# 50%     296.400000   288.750000   293.000000   292.425000   292.300000
# 75%     451.725000   438.775000   444.887500   444.837500   444.537500
# max     660.400000   646.500000   658.700000   655.400000   656.000000
# std     128.915075   127.333596   128.185881   128.175922   128.157873
#
#        previous_close  total_traded_qty  total_traded_volume     w52_high  \
# count      2294.00000      2.294000e+03         2.294000e+03  2294.000000
# mean        342.87925      2.589133e+07         8.137518e+09   664.717960
# min         150.85000      1.947722e+06         5.015678e+08   260.400000
# ...
